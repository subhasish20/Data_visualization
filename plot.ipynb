# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = sns.load_dataset("penguins")

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.boxplot(data=df,x='species',y='bill_length_mm')
# Out:
# <Axes: xlabel='species', ylabel='bill_length_mm'>

# %%
sns.swarmplot(data=df,x='species',y='bill_length_mm',hue='species')
# Out:
# c:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# c:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# <Axes: xlabel='species', ylabel='bill_length_mm'>

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df.pivot_table(index="species",values="bill_depth_mm",columns="island")
# Out:
# island        Biscoe      Dream  Torgersen
# species
# Adelie     18.370455  18.251786  18.429412
# Chinstrap        NaN  18.420588        NaN
# Gentoo     14.982114        NaN        NaN

# %%
titanic = sns.load_dataset("titanic")

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
x = titanic['age'].value_counts().iloc[0:15]

# %%
x
# Out:
# age
# 24.0    30
# 22.0    27
# 18.0    26
# 19.0    25
# 28.0    25
# 30.0    25
# 21.0    24
# 25.0    23
# 36.0    22
# 29.0    20
# 32.0    18
# 35.0    18
# 27.0    18
# 26.0    18
# 16.0    17
# Name: count, dtype: int64

# %%
pivote = titanic.pivot_table(index="age",columns='embark_town',values='fare')

# %%
pivote
# Out:
# embark_town  Cherbourg  Queenstown  Southampton
# age
# 0.42            8.5167         NaN          NaN
# 0.67               NaN         NaN       14.500
# 0.75           19.2583         NaN          NaN
# 0.83               NaN         NaN       23.875
# 0.92               NaN         NaN      151.550
# ...                ...         ...          ...
# 70.00              NaN         NaN       40.750
# 70.50              NaN        7.75          NaN
# 71.00          42.0792         NaN          NaN
# 74.00              NaN         NaN        7.775
# 80.00              NaN         NaN       30.000
#
# [88 rows x 3 columns]
